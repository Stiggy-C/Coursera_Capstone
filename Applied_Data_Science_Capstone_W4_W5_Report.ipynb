# %% [markdown]
# <h1>The Battle of Neighborhoods (Toronto [green] edition) - Report</h1>
# <h3 style="margin-top: 10px;">Result</h3>

# %%
# The code was removed by Watson Studio for sharing.

# %%
result_df
# Out:
#      Cluster label Postal code           Borough  \
# 0                1         M3A        North York
# 1                1         M4A        North York
# 2                0         M5A  Downtown Toronto
# 3                4         M6A        North York
# 4                0         M7A  Downtown Toronto
# 5                4         M9A         Etobicoke
# 6                1         M1B       Scarborough
# 7                1         M3B        North York
# 8                3         M4B         East York
# 9                0         M5B  Downtown Toronto
# 10               1         M6B        North York
# 11               1         M9B         Etobicoke
# 12               2         M1C       Scarborough
# 13               1         M3C        North York
# 14               3         M4C         East York
# 15               0         M5C  Downtown Toronto
# 16               0         M6C              York
# 17               1         M9C         Etobicoke
# ...

# %% [markdown]
# <h3>Summary</h3>

# %%
# Numbers of neighborhoods in each cluster:
result_df['Cluster label'].value_counts()
# Out:
# 0    38
# 1    23
# 4    21
# 2    11
# 3    10
# Name: Cluster label, dtype: int64

# %%
# Mean of total number of green zones for each cluster:
result_df.groupby('Cluster label')['Total Number of Green Zones'].agg(numpy.mean)
# Out:
# Cluster label
# 0    45.763158
# 1    23.086957
# 2     7.818182
# 3    32.300000
# 4    15.476190
# Name: Total Number of Green Zones, dtype: float64

# %%
# Mean of total number of W.I.P. (Waste Facility, Industrial Estate, Power Station) for each cluster:
result_df.groupby('Cluster label')['Total Number of W.I.P. Zones'].agg(numpy.mean)
# Out:
# Cluster label
# 0    0.736842
# 1    0.217391
# 2    1.000000
# 3    0.500000
# 4    1.238095
# Name: Total Number of W.I.P. Zones, dtype: float64

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
# ...

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - selenium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     selenium-3.141.0           |py36h8c4c3a4_1001         895 KB  conda-forge
#
# The following NEW packages will be INSTALLED:
#
#     selenium: 3.141.0-py36h8c4c3a4_1001 conda-forge
#
#
# ...
# selenium-3.141.0     | 895 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     nodejs-12.4.0              |       he1b5a44_0        18.1 MB  conda-forge
#
# The following NEW packages will be INSTALLED:
#
#     nodejs: 12.4.0-he1b5a44_0 conda-forge
#
#
# ...
# nodejs-12.4.0        | 18.1 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# npm WARN deprecated phantomjs-prebuilt@2.1.16: this package is now deprecated
# npm WARN deprecated request@2.88.2: request has been deprecated, see https://github.com/request/request/issues/3142
# /opt/conda/envs/Python36/bin/phantomjs -> /opt/conda/envs/Python36/lib/node_modules/phantomjs-prebuilt/bin/phantomjs
#
# > phantomjs-prebuilt@2.1.16 install /opt/conda/envs/Python36/lib/node_modules/phantomjs-prebuilt
# > node install.js
#
# Considering PhantomJS found at /opt/conda/envs/Python36/bin/phantomjs
# Looks like an `npm install -g`
# Could not link global install, skipping...
# ...
# Saving to /home/dsxuser/.tmp/phantomjs/phantomjs-2.1.1-linux-x86_64.tar.bz2
# Receiving...
#   [----------------------------------------] 0%  [=---------------------------------------] 3%  [==================----------------------] 44%
# Received 22866K total.
# Extracting tar contents (via spawned process)
# Removing /opt/conda/envs/Python36/lib/node_modules/phantomjs-prebuilt/lib/phantom
# ...

# %% [markdown]
# <h3>The big picture</h3>
# <div style="margin-top: 10px">
#     <ul>
#         <li>Red: Cluster 0</li>
#         <li>Purple: Cluster 1</li>
#         <li>Cyan: Cluster 2</li>
#         <li>Light blue: Cluster 3</li>
#         <li>Orange: Cluster 4</li>
#     </ul>
# </div>

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from IPython.display import Image
Image(img)

# %% [markdown]
# <div style="margin-top: 10px;">&emsp;&emsp;&emsp;Nowadays environmental topics are getting more popular. How green a neighborhood is may potentially interest a group of people. Toronto, one of the oldest and largest cities of Canada, which also is one of the most popular cities for immigrants, how green its neighborhoods will be of interest to a lot of people. Going over the summary of the result dataframes, one can probably observed the meaning of each cluster is as follow,</div>
# <div style="display: table; border: 1px solid #999999; margin-top: 10px;">
#     <div style="display: table-row; border: 1px solid #999999;">
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">Cluster</span>
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;"></span>
#     </div>
#     <div style="display: table-row; border: 1px solid #999999;">
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">0:</span>
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">Relatively high # of green zones, relatively moderate # of W.I.P. zones</span>
#     </div>
#     <div style="display: table-row; border: 1px solid #999999;">
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">1:</span>
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">Relatively moderate # of green zones, relatively low # of W.I.P. zones</span>
#     </div>
#     <div style="display: table-row; border: 1px solid #999999;">
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">2:</span>
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">Relatively low # of green zones, relatively high # of W.I.P. zones</span>
#     </div>
#     <div style="display: table-row; border: 1px solid #999999;">
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">3:</span>
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">Relatively high # of green zones, relatively low # of W.I.P. zones</span>
#     </div>
#     <div style="display: table-row; border: 1px solid #999999;">
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">4:</span>
#         <span style="display: table-cell; border: 1px solid #999999; font-weight: bold;">Relatively moderate # of green zones, relatively high # of W.I.P. zones</span>
#     </div>
# </div>
# <div style="margin-top: 10px;">However, one should not be tricked by the description. For example, cluster 2, even with "relatively high # of W.I.P. zones", the means of total number W.I.P. zones for the cluster is only 1 and the means of total number of green zones for the cluster is ~8. Therefore, for those neighborhoods, one can still expect there will be some green zone to enjoy and not too many W.I.P. zones in the neighborhoods which may harm his/her health. Therefore, within Toronto, neighborhoods do seem green. However, it may also means that industrial areas, power stations, waste facilities were moved outside of Toronto. Therefore, there may be a need for a wider and more comprehensive study to find out really how green Toronto neighborhoods are.</div>
